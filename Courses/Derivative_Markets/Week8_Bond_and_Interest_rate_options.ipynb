# %% [markdown]
# <a href="https://colab.research.google.com/github/1021114Carlos/MIT_MM_Finance/blob/Finance-shop/Courses/Derivative_Markets/Week8_Bond_and_Interest_rate_options.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
from scipy.stats import norm

# %% [markdown]
# (Q1.A)

# %%
rfr = 7.18/100
t_coupon = 3/13
t = 8/12
vol = 9.26/100
pv_coupon = 35*math.exp(-rfr*t_coupon)
bond_price_S0 = 910
# price of the bond excluding coupon
S0 = bond_price_S0 - pv_coupon
S0

# Forward price should > S0 because of interest
F0 = S0*math.exp(rfr*t)


d1 = (math.log(F0/S0) + (1/2)*(vol**2)*t)/vol*math.sqrt(t)
d2 = d1 - vol*math.sqrt(t)
d1, d2
prob_dist = d1 - d2

# black formula for european put
P0 = math.exp(-rfr*t)*prob_dist
P0

# %%
d1 = math.log(F0/S0) + (1/2)*
